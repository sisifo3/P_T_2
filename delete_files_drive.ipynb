# %% [markdown]
# <a href="https://colab.research.google.com/github/sisifo3/P_T_2/blob/main/delete_files_drive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm '/content/drive/MyDrive/train_circle1000.npy'

# %%
j = 1199
for i in range(200):
  e = j + i
  b = str(e)
  a = 'train_circle'  
  c = ".npy'"
  file_name = "'/content/drive/MyDrive/"
  name = file_name + a+b+c
  print("!rm ",name)
  #!rm name
  #/content/drive/MyDrive/train_circle10.npy
# Out:
# !rm  '/content/drive/MyDrive/train_circle1199.npy'
# !rm  '/content/drive/MyDrive/train_circle1200.npy'
# !rm  '/content/drive/MyDrive/train_circle1201.npy'
# !rm  '/content/drive/MyDrive/train_circle1202.npy'
# !rm  '/content/drive/MyDrive/train_circle1203.npy'
# !rm  '/content/drive/MyDrive/train_circle1204.npy'
# !rm  '/content/drive/MyDrive/train_circle1205.npy'
# !rm  '/content/drive/MyDrive/train_circle1206.npy'
# !rm  '/content/drive/MyDrive/train_circle1207.npy'
# !rm  '/content/drive/MyDrive/train_circle1208.npy'
# !rm  '/content/drive/MyDrive/train_circle1209.npy'
# !rm  '/content/drive/MyDrive/train_circle1210.npy'
# !rm  '/content/drive/MyDrive/train_circle1211.npy'
# !rm  '/content/drive/MyDrive/train_circle1212.npy'
# !rm  '/content/drive/MyDrive/train_circle1213.npy'
# !rm  '/content/drive/MyDrive/train_circle1214.npy'
# !rm  '/content/drive/MyDrive/train_circle1215.npy'
# !rm  '/content/drive/MyDrive/train_circle1216.npy'
# ...

# %%
# !rm  '/content/drive/MyDrive/train_circle1199.npy'
# !rm  '/content/drive/MyDrive/train_circle1200.npy'
# !rm  '/content/drive/MyDrive/train_circle1201.npy'
# !rm  '/content/drive/MyDrive/train_circle1202.npy'
# !rm  '/content/drive/MyDrive/train_circle1203.npy'
# !rm  '/content/drive/MyDrive/train_circle1204.npy'
# !rm  '/content/drive/MyDrive/train_circle1205.npy'
# !rm  '/content/drive/MyDrive/train_circle1206.npy'
# !rm  '/content/drive/MyDrive/train_circle1207.npy'
# !rm  '/content/drive/MyDrive/train_circle1208.npy'
# !rm  '/content/drive/MyDrive/train_circle1209.npy'
# !rm  '/content/drive/MyDrive/train_circle1210.npy'
# !rm  '/content/drive/MyDrive/train_circle1211.npy'
# !rm  '/content/drive/MyDrive/train_circle1212.npy'
# !rm  '/content/drive/MyDrive/train_circle1213.npy'
# !rm  '/content/drive/MyDrive/train_circle1214.npy'
# !rm  '/content/drive/MyDrive/train_circle1215.npy'
# !rm  '/content/drive/MyDrive/train_circle1216.npy'
# !rm  '/content/drive/MyDrive/train_circle1217.npy'
# !rm  '/content/drive/MyDrive/train_circle1218.npy'
# !rm  '/content/drive/MyDrive/train_circle1219.npy'
# !rm  '/content/drive/MyDrive/train_circle1220.npy'
# !rm  '/content/drive/MyDrive/train_circle1221.npy'
# !rm  '/content/drive/MyDrive/train_circle1222.npy'
# !rm  '/content/drive/MyDrive/train_circle1223.npy'
# !rm  '/content/drive/MyDrive/train_circle1224.npy'
# !rm  '/content/drive/MyDrive/train_circle1225.npy'
# !rm  '/content/drive/MyDrive/train_circle1226.npy'
# !rm  '/content/drive/MyDrive/train_circle1227.npy'
# !rm  '/content/drive/MyDrive/train_circle1228.npy'
# !rm  '/content/drive/MyDrive/train_circle1229.npy'
# !rm  '/content/drive/MyDrive/train_circle1230.npy'
# !rm  '/content/drive/MyDrive/train_circle1231.npy'
# !rm  '/content/drive/MyDrive/train_circle1232.npy'
# !rm  '/content/drive/MyDrive/train_circle1233.npy'
# !rm  '/content/drive/MyDrive/train_circle1234.npy'
# !rm  '/content/drive/MyDrive/train_circle1235.npy'
# !rm  '/content/drive/MyDrive/train_circle1236.npy'
# !rm  '/content/drive/MyDrive/train_circle1237.npy'
# !rm  '/content/drive/MyDrive/train_circle1238.npy'
# !rm  '/content/drive/MyDrive/train_circle1239.npy'
# !rm  '/content/drive/MyDrive/train_circle1240.npy'
# !rm  '/content/drive/MyDrive/train_circle1241.npy'
# !rm  '/content/drive/MyDrive/train_circle1242.npy'
# !rm  '/content/drive/MyDrive/train_circle1243.npy'
# !rm  '/content/drive/MyDrive/train_circle1244.npy'
# !rm  '/content/drive/MyDrive/train_circle1245.npy'
# !rm  '/content/drive/MyDrive/train_circle1246.npy'
# !rm  '/content/drive/MyDrive/train_circle1247.npy'
# !rm  '/content/drive/MyDrive/train_circle1248.npy'
# !rm  '/content/drive/MyDrive/train_circle1249.npy'
# !rm  '/content/drive/MyDrive/train_circle1250.npy'
# !rm  '/content/drive/MyDrive/train_circle1251.npy'
# !rm  '/content/drive/MyDrive/train_circle1252.npy'
# !rm  '/content/drive/MyDrive/train_circle1253.npy'
# !rm  '/content/drive/MyDrive/train_circle1254.npy'
# !rm  '/content/drive/MyDrive/train_circle1255.npy'
# !rm  '/content/drive/MyDrive/train_circle1256.npy'
# !rm  '/content/drive/MyDrive/train_circle1257.npy'
# !rm  '/content/drive/MyDrive/train_circle1258.npy'
# !rm  '/content/drive/MyDrive/train_circle1259.npy'
# !rm  '/content/drive/MyDrive/train_circle1260.npy'
# !rm  '/content/drive/MyDrive/train_circle1261.npy'
# !rm  '/content/drive/MyDrive/train_circle1262.npy'
# !rm  '/content/drive/MyDrive/train_circle1263.npy'
# !rm  '/content/drive/MyDrive/train_circle1264.npy'
# !rm  '/content/drive/MyDrive/train_circle1265.npy'
# !rm  '/content/drive/MyDrive/train_circle1266.npy'
# !rm  '/content/drive/MyDrive/train_circle1267.npy'
# !rm  '/content/drive/MyDrive/train_circle1268.npy'
# !rm  '/content/drive/MyDrive/train_circle1269.npy'
# !rm  '/content/drive/MyDrive/train_circle1270.npy'
# !rm  '/content/drive/MyDrive/train_circle1271.npy'
# !rm  '/content/drive/MyDrive/train_circle1272.npy'
# !rm  '/content/drive/MyDrive/train_circle1273.npy'
# !rm  '/content/drive/MyDrive/train_circle1274.npy'
# !rm  '/content/drive/MyDrive/train_circle1275.npy'
# !rm  '/content/drive/MyDrive/train_circle1276.npy'
# !rm  '/content/drive/MyDrive/train_circle1277.npy'
# !rm  '/content/drive/MyDrive/train_circle1278.npy'
# !rm  '/content/drive/MyDrive/train_circle1279.npy'
# !rm  '/content/drive/MyDrive/train_circle1280.npy'
# !rm  '/content/drive/MyDrive/train_circle1281.npy'
# !rm  '/content/drive/MyDrive/train_circle1282.npy'
# !rm  '/content/drive/MyDrive/train_circle1283.npy'
# !rm  '/content/drive/MyDrive/train_circle1284.npy'
# !rm  '/content/drive/MyDrive/train_circle1285.npy'
# !rm  '/content/drive/MyDrive/train_circle1286.npy'
# !rm  '/content/drive/MyDrive/train_circle1287.npy'
# !rm  '/content/drive/MyDrive/train_circle1288.npy'
# !rm  '/content/drive/MyDrive/train_circle1289.npy'
# !rm  '/content/drive/MyDrive/train_circle1290.npy'
# !rm  '/content/drive/MyDrive/train_circle1291.npy'
# !rm  '/content/drive/MyDrive/train_circle1292.npy'
# !rm  '/content/drive/MyDrive/train_circle1293.npy'
# !rm  '/content/drive/MyDrive/train_circle1294.npy'
# !rm  '/content/drive/MyDrive/train_circle1295.npy'
# !rm  '/content/drive/MyDrive/train_circle1296.npy'
# !rm  '/content/drive/MyDrive/train_circle1297.npy'
# !rm  '/content/drive/MyDrive/train_circle1298.npy'
# !rm  '/content/drive/MyDrive/train_circle1299.npy'
# !rm  '/content/drive/MyDrive/train_circle1300.npy'
# !rm  '/content/drive/MyDrive/train_circle1301.npy'
# !rm  '/content/drive/MyDrive/train_circle1302.npy'
# !rm  '/content/drive/MyDrive/train_circle1303.npy'
# !rm  '/content/drive/MyDrive/train_circle1304.npy'
# !rm  '/content/drive/MyDrive/train_circle1305.npy'
# !rm  '/content/drive/MyDrive/train_circle1306.npy'
# !rm  '/content/drive/MyDrive/train_circle1307.npy'
# !rm  '/content/drive/MyDrive/train_circle1308.npy'
# !rm  '/content/drive/MyDrive/train_circle1309.npy'
# !rm  '/content/drive/MyDrive/train_circle1310.npy'
# !rm  '/content/drive/MyDrive/train_circle1311.npy'
# !rm  '/content/drive/MyDrive/train_circle1312.npy'
# !rm  '/content/drive/MyDrive/train_circle1313.npy'
# !rm  '/content/drive/MyDrive/train_circle1314.npy'
# !rm  '/content/drive/MyDrive/train_circle1315.npy'
# !rm  '/content/drive/MyDrive/train_circle1316.npy'
# !rm  '/content/drive/MyDrive/train_circle1317.npy'
# !rm  '/content/drive/MyDrive/train_circle1318.npy'
# !rm  '/content/drive/MyDrive/train_circle1319.npy'
# !rm  '/content/drive/MyDrive/train_circle1320.npy'
# !rm  '/content/drive/MyDrive/train_circle1321.npy'
# !rm  '/content/drive/MyDrive/train_circle1322.npy'
# !rm  '/content/drive/MyDrive/train_circle1323.npy'
# !rm  '/content/drive/MyDrive/train_circle1324.npy'
# !rm  '/content/drive/MyDrive/train_circle1325.npy'
# !rm  '/content/drive/MyDrive/train_circle1326.npy'
# !rm  '/content/drive/MyDrive/train_circle1327.npy'
# !rm  '/content/drive/MyDrive/train_circle1328.npy'
# !rm  '/content/drive/MyDrive/train_circle1329.npy'
# !rm  '/content/drive/MyDrive/train_circle1330.npy'
# !rm  '/content/drive/MyDrive/train_circle1331.npy'
# !rm  '/content/drive/MyDrive/train_circle1332.npy'
# !rm  '/content/drive/MyDrive/train_circle1333.npy'
# !rm  '/content/drive/MyDrive/train_circle1334.npy'
# !rm  '/content/drive/MyDrive/train_circle1335.npy'
# !rm  '/content/drive/MyDrive/train_circle1336.npy'
# !rm  '/content/drive/MyDrive/train_circle1337.npy'
# !rm  '/content/drive/MyDrive/train_circle1338.npy'
# !rm  '/content/drive/MyDrive/train_circle1339.npy'
# !rm  '/content/drive/MyDrive/train_circle1340.npy'
# !rm  '/content/drive/MyDrive/train_circle1341.npy'
# !rm  '/content/drive/MyDrive/train_circle1342.npy'
# !rm  '/content/drive/MyDrive/train_circle1343.npy'
# !rm  '/content/drive/MyDrive/train_circle1344.npy'
# !rm  '/content/drive/MyDrive/train_circle1345.npy'
# !rm  '/content/drive/MyDrive/train_circle1346.npy'
# !rm  '/content/drive/MyDrive/train_circle1347.npy'
# !rm  '/content/drive/MyDrive/train_circle1348.npy'
# !rm  '/content/drive/MyDrive/train_circle1349.npy'
# !rm  '/content/drive/MyDrive/train_circle1350.npy'
# !rm  '/content/drive/MyDrive/train_circle1351.npy'
# !rm  '/content/drive/MyDrive/train_circle1352.npy'
# !rm  '/content/drive/MyDrive/train_circle1353.npy'
# !rm  '/content/drive/MyDrive/train_circle1354.npy'
# !rm  '/content/drive/MyDrive/train_circle1355.npy'
# !rm  '/content/drive/MyDrive/train_circle1356.npy'
# !rm  '/content/drive/MyDrive/train_circle1357.npy'
# !rm  '/content/drive/MyDrive/train_circle1358.npy'
# !rm  '/content/drive/MyDrive/train_circle1359.npy'
# !rm  '/content/drive/MyDrive/train_circle1360.npy'
# !rm  '/content/drive/MyDrive/train_circle1361.npy'
# !rm  '/content/drive/MyDrive/train_circle1362.npy'
# !rm  '/content/drive/MyDrive/train_circle1363.npy'
# !rm  '/content/drive/MyDrive/train_circle1364.npy'
# !rm  '/content/drive/MyDrive/train_circle1365.npy'
# !rm  '/content/drive/MyDrive/train_circle1366.npy'
# !rm  '/content/drive/MyDrive/train_circle1367.npy'
# !rm  '/content/drive/MyDrive/train_circle1368.npy'
# !rm  '/content/drive/MyDrive/train_circle1369.npy'
# !rm  '/content/drive/MyDrive/train_circle1370.npy'
# !rm  '/content/drive/MyDrive/train_circle1371.npy'
# !rm  '/content/drive/MyDrive/train_circle1372.npy'
# !rm  '/content/drive/MyDrive/train_circle1373.npy'
# !rm  '/content/drive/MyDrive/train_circle1374.npy'
# !rm  '/content/drive/MyDrive/train_circle1375.npy'
# !rm  '/content/drive/MyDrive/train_circle1376.npy'
# !rm  '/content/drive/MyDrive/train_circle1377.npy'
# !rm  '/content/drive/MyDrive/train_circle1378.npy'
# !rm  '/content/drive/MyDrive/train_circle1379.npy'
# !rm  '/content/drive/MyDrive/train_circle1380.npy'
# !rm  '/content/drive/MyDrive/train_circle1381.npy'
# !rm  '/content/drive/MyDrive/train_circle1382.npy'
# !rm  '/content/drive/MyDrive/train_circle1383.npy'
# !rm  '/content/drive/MyDrive/train_circle1384.npy'
# !rm  '/content/drive/MyDrive/train_circle1385.npy'
# !rm  '/content/drive/MyDrive/train_circle1386.npy'
# !rm  '/content/drive/MyDrive/train_circle1387.npy'
# !rm  '/content/drive/MyDrive/train_circle1388.npy'
# !rm  '/content/drive/MyDrive/train_circle1389.npy'
# !rm  '/content/drive/MyDrive/train_circle1390.npy'
# !rm  '/content/drive/MyDrive/train_circle1391.npy'
# !rm  '/content/drive/MyDrive/train_circle1392.npy'
# !rm  '/content/drive/MyDrive/train_circle1393.npy'
# !rm  '/content/drive/MyDrive/train_circle1394.npy'
# !rm  '/content/drive/MyDrive/train_circle1395.npy'
# !rm  '/content/drive/MyDrive/train_circle1396.npy'
# !rm  '/content/drive/MyDrive/train_circle1397.npy'
# !rm  '/content/drive/MyDrive/train_circle1398.npy'
# Out:
# rm: cannot remove '/content/drive/MyDrive/train_circle1199.npy': No such file or directory
